# %% [markdown]
# #**Lab 07-4 MNIST introduction**
#
# * MNIST(Modified National Institute of Standards and Technology database)는 0~9까지의 순으로 쓴 숫자들로 이루어진 대형 데이터베이스

# %% [markdown]
# ##**기본 Library 선언 및 Tensorflow 버전 확인**

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(777)
print(tf.__version__)
# Out:
# 2.4.0

# %% [markdown]
# ##**사용할 Data**
#
# * Tensorflow 2.0 버전에 맞게 Keras를 활용한 MNIST를 분류 모델로 생성

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ##**Tensorflow Keras**
#
# **위 Data를 기준으로 분류 모델을 만든다.**
#
# * Tensorflow keras API를 통해 모델에 대한 정의

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# * Adam Optimizer와 Cross Entropy Loss 선언

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# * 5 Epoch로 학습할 Data로 학습 수행

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3597 - accuracy: 0.8940
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0987 - accuracy: 0.9702
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0683 - accuracy: 0.9786
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0513 - accuracy: 0.9840
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0407 - accuracy: 0.9867

# %% [markdown]
# * 모델을 평가할 Test 데이터에 대한 정의

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0602 - accuracy: 0.9824
# [0.06017936393618584, 0.9824000000953674]
